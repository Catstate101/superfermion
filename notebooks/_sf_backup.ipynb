# %% [markdown]
# # SuperFermion Live Demo
# **One framework. Every qubit. Every gradient. Every model.**
#
# This notebook shows:
# 1. Building quantum circuits with SuperFermion
# 2. Visualizing circuits (ASCII diagrams + OpenQASM 3)
# 3. SF-native transpilation & compilation for hardware
# 4. Running local simulations (multiple backends)
# 5. Connecting to **real IBM Quantum hardware** via SF
# 6. Submitting circuits to IBM QPU & fetching results
# 7. Noise data & error characterization from real hardware
# 8. **MPS Tensor Networks** — 50+ qubit scaling
# 9. **QML** — VQE ground state & QAOA MaxCut
# 10. **Adjoint gradients** — O(1) differentiation
# 11. **QEC codes** — Repetition, Shor, Steane, Surface
# 12. **Benchpress** — SF vs Qiskit vs PennyLane (live benchmarks)

# %% [markdown]
# ---
# ## 1. Setup — Load credentials & imports

# %%
import os, sys, time, json, math, warnings
from pathlib import Path
warnings.filterwarnings('ignore')

# Point to project root
ROOT = Path.cwd().parent if 'notebooks' in str(Path.cwd()) else Path.cwd()
sys.path.insert(0, str(ROOT))

from dotenv import load_dotenv
load_dotenv(ROOT / '.env')

IBM_TOKEN = os.getenv('IBM_QUANTUM_TOKEN', '')
IONQ_KEY  = os.getenv('IONQ_API_KEY', '')

print(f'IBM Token loaded:  {"YES" if IBM_TOKEN else "MISSING - check .env"}')
print(f'IonQ Key loaded:   {"YES" if IONQ_KEY else "MISSING - check .env"}')
print(f'Project root:      {ROOT}')
# Out:
# IBM Token loaded:  YES
# IonQ Key loaded:   YES
# Project root:      c:\Users\ASUS\OneDrive\Desktop\superfermion

# %%
import numpy as np
import superfermion as sf

print(f'SuperFermion v{sf.__version__}')
print(f'Available backends: {sf.list_backends()}')
# Out:
# SuperFermion v0.1.0
# Available backends: ['statevector', 'jax', 'cuda', 'mps', 'singularity', 'stabilizer']

# %% [markdown]
# ---
# ## 2. Build Circuits — SuperFermion Fluent API
#
# SF uses a fluent, chainable API. Build any circuit in pure Python — no Qiskit needed.

# %%
# Bell State (2 qubits) — H on qubit 0, then CNOT(0,1)
bell = sf.Circuit(2)
bell.h(0)
bell.cx(0, 1)
print(f'Bell State: {bell.n_qubits} qubits, {bell.gate_count} gates, depth={bell.depth}')

# GHZ State (3 qubits) — maximally entangled
ghz = sf.Circuit(3)
ghz.h(0); ghz.cx(0, 1); ghz.cx(1, 2)
print(f'GHZ-3: {ghz.n_qubits} qubits, {ghz.gate_count} gates')

# QFT (4 qubits)
qft = sf.Circuit(4)
for j in range(4):
    qft.h(j)
    for k in range(j + 1, 4):
        qft.cp(math.pi / (2 ** (k - j)), k, j)
for i in range(2): qft.swap(i, 3 - i)
print(f'QFT-4: {qft.n_qubits} qubits, {qft.gate_count} gates')

# Grover Search (2 qubits, target=|11>)
grover = sf.Circuit(2)
grover.h(0); grover.h(1)
grover.cz(0, 1)               # oracle for |11>
grover.h(0); grover.h(1)     # diffusion
grover.x(0); grover.x(1); grover.cz(0, 1); grover.x(0); grover.x(1)
grover.h(0); grover.h(1)
print(f'Grover-|11>: {grover.n_qubits} qubits, {grover.gate_count} gates')
# Out:
# Bell State: 2 qubits, 2 gates, depth=2
# GHZ-3: 3 qubits, 3 gates
# QFT-4: 4 qubits, 12 gates
# Grover-|11>: 2 qubits, 12 gates

# %% [markdown]
# ---
# ## 3. Visualize Circuits — SF-Native Drawing
#
# SF can draw circuits as ASCII art and export to OpenQASM 3.0 — no external tools needed.

# %%
# ASCII circuit diagrams — built into SF
print('=' * 50)
print('  BELL STATE — circuit diagram')
print('=' * 50)
print(bell.draw())

print()
print('=' * 50)
print('  GHZ-3 — circuit diagram')
print('=' * 50)
print(ghz.draw())

print()
print('=' * 50)
print('  GROVER |11> — circuit diagram')
print('=' * 50)
print(grover.draw())
# Out:
# ==================================================
#   BELL STATE — circuit diagram
# ==================================================
# q0: ─  [H]  ─   ●   ─
# q1: ─  ───  ─   ⊕   ─
#
# ==================================================
#   GHZ-3 — circuit diagram
# ==================================================
# q0: ─  [H]  ─   ●   ─  ───  ─
# q1: ─  ───  ─   ⊕   ─   ●   ─
# q2: ─  ───  ─  ───  ─   ⊕   ─
#
# ==================================================
#   GROVER |11> — circuit diagram
# ==================================================
# q0: ─  [H]  ─  ───  ─   ●   ─  [H]  ─  ───  ─  [X]  ─  ───  ─   ●   ─  [X]  ─  ───  ─  [H]  ─  ───  ─
# q1: ─  ───  ─  [H]  ─   ●   ─  ───  ─  [H]  ─  ───  ─  [X]  ─   ●   ─  ───  ─  [X]  ─  ───  ─  [H]  ─

# %%
# QFT-4 is larger — show it separately
print('=' * 60)
print('  QFT-4 — circuit diagram (4 qubits)')
print('=' * 60)
print(qft.draw())
# Out:
# ============================================================
#   QFT-4 — circuit diagram (4 qubits)
# ============================================================
# q0: ─  [H]  ─ [CP]  ─ [CP]  ─ [CP]  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─[SWAP] ─  ───  ─
# q1: ─  ───  ─ [CP]  ─   │   ─   │   ─  [H]  ─ [CP]  ─ [CP]  ─  ───  ─  ───  ─  ───  ─   │   ─[SWAP] ─
# q2: ─  ───  ─  ───  ─ [CP]  ─   │   ─  ───  ─ [CP]  ─   │   ─  [H]  ─ [CP]  ─  ───  ─   │   ─[SWAP] ─
# q3: ─  ───  ─  ───  ─  ───  ─ [CP]  ─  ───  ─  ───  ─ [CP]  ─  ───  ─ [CP]  ─  [H]  ─[SWAP] ─  ───  ─
# ============================================================
# q0: ─  [H]  ─ [CP]  ─ [CP]  ─ [CP]  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─[SWAP] ─  ───  ─
# q1: ─  ───  ─ [CP]  ─   │   ─   │   ─  [H]  ─ [CP]  ─ [CP]  ─  ───  ─  ───  ─  ───  ─   │   ─[SWAP] ─
# q2: ─  ───  ─  ───  ─ [CP]  ─   │   ─  ───  ─ [CP]  ─   │   ─  [H]  ─ [CP]  ─  ───  ─   │   ─[SWAP] ─
# q3: ─  ───  ─  ───  ─  ───  ─ [CP]  ─  ───  ─  ───  ─ [CP]  ─  ───  ─ [CP]  ─  [H]  ─[SWAP] ─  ───  ─

# %%
# OpenQASM 3.0 export — SF generates standard quantum assembly
print('=== Bell State — OpenQASM 3.0 ===')
print(bell.to_qasm3())

print('=== GHZ-3 — OpenQASM 3.0 ===')
print(ghz.to_qasm3())
# Out:
# === Bell State — OpenQASM 3.0 ===
# OPENQASM 3.0;
# qubit[2] q;
# bit[2] c;
#
# h q[0];
# cx q[0], q[1];
#
# === GHZ-3 — OpenQASM 3.0 ===
# OPENQASM 3.0;
# qubit[3] q;
# bit[3] c;
#
# h q[0];
# cx q[0], q[1];
# cx q[1], q[2];

# %% [markdown]
# ---
# ## 4. SF-Native Transpilation & Compilation
#
# SF has its own compiler pipeline — gate cancellation, rotation merging,
# basis translation, and SABRE routing. **No Qiskit transpiler needed.**
#
# We define a hardware target and compile the circuit for it.

# %%
from superfermion.compiler import compile as sf_compile
from superfermion.runtime.specs import HardwareSpec

# Define a hardware target (IBM-style, basis translation only)
ibm_target = HardwareSpec(
    name='ibm_sherbrooke_like',
    n_qubits=127,
    native_gates=['rz', 'sx', 'x', 'cx'],   # IBM native gate set
    coupling_map=[],  # empty = no routing, just basis translation
)

print(f'Target: {ibm_target.name}')
print(f'  Qubits: {ibm_target.n_qubits}')
print(f'  Native gates: {ibm_target.native_gates}')
print(f'  Routing: skipped (no coupling map)')
# Out:
# Target: ibm_sherbrooke_like
#   Qubits: 127
#   Native gates: ['rz', 'sx', 'x', 'cx']
#   Routing: skipped (no coupling map)

# %%
# Transpile Bell state for IBM hardware
print('=== Before compilation ===')
print(f'  Gates: {bell.gate_count}, Depth: {bell.depth}')
print(bell.draw())

print()
print('=== After SF compilation (level=1, IBM target) ===')
bell_compiled = sf_compile(bell, level=1, target=ibm_target)
print(f'  Gates: {bell_compiled.gate_count}, Depth: {bell_compiled.depth}')
print(bell_compiled.draw())

print()
print('=== QASM3 after transpilation ===')
print(bell_compiled.to_qasm3())
# Out:
# === Before compilation ===
#   Gates: 2, Depth: 2
# q0: ─  [H]  ─   ●   ─
# q1: ─  ───  ─   ⊕   ─
#
# === After SF compilation (level=1, IBM target) ===
#   Gates: 4, Depth: 4
# q0: ─[RZ(1.57)]─[RX(1.57)]─[RZ(1.57)]─   ●   ─
# q1: ─  ───  ─  ───  ─  ───  ─   ⊕   ─
#
# === QASM3 after transpilation ===
# OPENQASM 3.0;
# qubit[2] q;
# bit[2] c;
#
# rz(1.570796) q[0];
# rx(1.570796) q[0];
# rz(1.570796) q[0];
# cx q[0], q[1];

# %%
# Transpile GHZ-3 — watch H decompose to RZ+SX+RZ
print('=== GHZ-3 — Before ===')
print(f'  Gates: {ghz.gate_count}, Depth: {ghz.depth}')
print(ghz.draw())

ghz_compiled = sf_compile(ghz, level=1, target=ibm_target)
print()
print('=== GHZ-3 — After SF transpilation ===')
print(f'  Gates: {ghz_compiled.gate_count}, Depth: {ghz_compiled.depth}')
print(ghz_compiled.draw())

# Compare gate counts
from collections import Counter
orig = Counter(g.name for g in ghz._gates)
compiled = Counter(g.name for g in ghz_compiled._gates)
print()
print('Gate breakdown:')
print(f'  {"Gate":<8} {"Original":<10} {"Compiled"}')
print(f'  {"-"*30}')
all_gates = set(list(orig.keys()) + list(compiled.keys()))
for g in sorted(all_gates):
    print(f'  {g:<8} {orig.get(g, 0):<10} {compiled.get(g, 0)}')
# Out:
# === GHZ-3 — Before ===
#   Gates: 3, Depth: 3
# q0: ─  [H]  ─   ●   ─  ───  ─
# q1: ─  ───  ─   ⊕   ─   ●   ─
# q2: ─  ───  ─  ───  ─   ⊕   ─
#
# === GHZ-3 — After SF transpilation ===
#   Gates: 5, Depth: 5
# q0: ─[RZ(1.57)]─[RX(1.57)]─[RZ(1.57)]─   ●   ─  ───  ─
# q1: ─  ───  ─  ───  ─  ───  ─   ⊕   ─   ●   ─
# q2: ─  ───  ─  ───  ─  ───  ─  ───  ─   ⊕   ─
#
# Gate breakdown:
#   Gate     Original   Compiled
#   ------------------------------
#   CNOT     2          2
#   H        1          0
#   RX       0          1
#   RZ       0          2

# %%
# Transpile QFT-4 at different optimization levels
print('=== QFT-4 — Compilation at different levels ===')
print(f'{"Level":<8} {"Gates":<8} {"Depth":<8} {"Time (ms)"}')
print('-' * 40)

# Level 0 = no optimization (just return original)
# Level 1 = swap decomposition + gate cancellation + rotation merging + basis translation
for level in [0, 1]:
    t0 = time.perf_counter()
    c = sf_compile(qft, level=level, target=ibm_target)
    dt = (time.perf_counter() - t0) * 1000
    print(f'  {level:<6} {c.gate_count:<8} {c.depth:<8} {dt:.2f}')

# Show the compiled QFT at level 1
qft_compiled = sf_compile(qft, level=1, target=ibm_target)
print(f'\nCompiled QFT-4 (level=1):')
print(qft_compiled.draw())
# Out:
# === QFT-4 — Compilation at different levels ===
# Level    Gates    Depth    Time (ms)
# ----------------------------------------
#   0      20       16       0.09
#   1      24       18       0.13
#
# Compiled QFT-4 (level=1):
# q0: ─[RZ(1.57)]─[RX(1.57)]─[RZ(1.57)]─ [CP]  ─ [CP]  ─ [CP]  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─   ●   ─   ⊕   ─   ●   ─  ───  ─  ───  ─  ───  ─
# q1: ─  ───  ─  ───  ─  ───  ─ [CP]  ─   │   ─   │   ─[RZ(1.57)]─[RX(1.57)]─[RZ(1.57)]─ [CP]  ─ [CP]  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─   │   ─   │   ─   │   ─   ●   ─   ⊕   ─   ●   ─
# q2: ─  ───  ─  ───  ─  ───  ─  ───  ─ [CP]  ─   │   ─  ───  ─  ───  ─  ───  ─ [CP]  ─   │   ─[RZ(1.57)]─[RX(1.57)]─[RZ(1.57)]─ [CP]  ─  ───  ─  ───  ─  ───  ─   │   ─   │   ─   │   ─   ⊕   ─   ●   ─   ⊕   ─
# q3: ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─ [CP]  ─  ───  ─  ───  ─  ───  ─  ───  ─ [CP]  ─  ───  ─  ───  ─  ───  ─ [CP]  ─[RZ(1.57)]─[RX(1.57)]─[RZ(1.57)]─   ⊕   ─   ●   ─   ⊕   ─  ───  ─  ───  ─  ───  ─

# %% [markdown]
# ---
# ## 5. Local Simulation — Run on SF backends

# %%
# Run Bell state on statevector backend
result = sf.run(bell, backend='statevector', shots=1000)

print('=== Bell State (statevector, 1000 shots) ===')
total = sum(result.counts.values())
for state, count in sorted(result.counts.items(), key=lambda x: -x[1]):
    pct = count / total * 100
    bar = '#' * int(pct / 2)
    print(f'  |{state}> : {count:4d} ({pct:5.1f}%) {bar}')
# Out:
# === Bell State (statevector, 1000 shots) ===
#   |11> :  510 ( 51.0%) #########################
#   |00> :  490 ( 49.0%) ########################

# %%
# Run all circuits across multiple backends
circuits = {'Bell': bell, 'GHZ-3': ghz, 'QFT-4': qft, 'Grover': grover}
backends_to_try = ['statevector', 'jax', 'singularity', 'mps']

print(f'{"Circuit":<12} {"Backend":<14} {"Time(ms)":<10} Top States')
print('-' * 72)

for cname, circ in circuits.items():
    for bk_name in backends_to_try:
        try:
            t0 = time.perf_counter()
            r = sf.run(circ, backend=bk_name, shots=1024)
            dt = (time.perf_counter() - t0) * 1000
            top3 = sorted(r.counts.items(), key=lambda x: -x[1])[:3]
            top_str = ', '.join(f'{s}={c}' for s, c in top3)
            print(f'  {cname:<10} {bk_name:<14} {dt:<10.2f} {top_str}')
        except Exception as e:
            print(f'  {cname:<10} {bk_name:<14} {"SKIP":<10} ({str(e)[:40]})')
# Out:
# Circuit      Backend        Time(ms)   Top States
# ------------------------------------------------------------------------
#   Bell       statevector    2.02       00=529, 11=495
#   Bell       jax            2033.10    00=546, 11=478
#   Bell       singularity    2.57       00=515, 11=509
#   Bell       mps            126.98     00=522, 11=502
#   GHZ-3      statevector    1.43       000=522, 111=502
#   GHZ-3      jax            503.88     000=546, 111=478
#   GHZ-3      singularity    1.05       000=515, 111=509
#   GHZ-3      mps            148.31     000=526, 111=498
#   QFT-4      statevector    2.61       0111=73, 0011=71, 1000=70
#   QFT-4      jax            608.53     0011=80, 0001=73, 0110=73
#   QFT-4      singularity    2.46       0010=77, 1100=72, 0111=70
#   QFT-4      mps            186.30     0000=74, 1100=74, 1000=73
#   Grover     statevector    1.93       11=1024
#   Grover     jax            72.79      11=1024
#   Grover     singularity    3.69       11=1024
#   Grover     mps            95.56      11=1024

# %% [markdown]
# ---
# ## 6. Connect to IBM Quantum — via SF IBMProvider
#
# SF's `IBMProvider` wraps IBM Quantum. One import, one line to connect.

# %%
if not IBM_TOKEN:
    print('ERROR: No IBM token found. Set IBM_QUANTUM_TOKEN in .env')
else:
    from superfermion.runtime.providers.ibm import IBMProvider
    ibm = IBMProvider(token=IBM_TOKEN)
    print('Connected to IBM Quantum via SF IBMProvider!')

    # List available backends — pure SF API
    backends_info = ibm.list_backends()
    print(f'\nAvailable QPUs: {len(backends_info)}')
    print(f'{"Name":<24} {"Qubits":<8} {"Pending Jobs":<14} {"Status"}')
    print('-' * 60)
    for b in backends_info:
        nq = b.get('num_qubits', '?')
        pending = b.get('pending_jobs', '?')
        status = b.get('status_msg', '?')
        print(f'  {b["name"]:<22} {str(nq):<8} {str(pending):<14} {status}')

    # Pick the best target (most qubits)
    TARGET = max(backends_info, key=lambda b: b.get('num_qubits', 0) if isinstance(b.get('num_qubits'), int) else 0)['name']
    target_nq = next(b['num_qubits'] for b in backends_info if b['name'] == TARGET)
    print(f'\nSelected target: {TARGET} ({target_nq} qubits)')
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-06-12 03:09:13,543: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-06-12 03:09:22,661: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-06-12 03:09:22,662: Loading instance: open-instance, plan: open
# Connected to IBM Quantum via SF IBMProvider!
# Available QPUs: 3
# Name                     Qubits   Pending Jobs   Status
# ------------------------------------------------------------
#   ibm_fez                156      2              active
#   ibm_marrakesh          156      6              active
#   ibm_kingston           156      63             active
#
# Selected target: ibm_fez (156 qubits)

# %% [markdown]
# ---
# ## 7. Noise Data from Real Hardware
#
# Fetch live T1, T2, readout error from the IBM QPU through SF.

# %%
if not IBM_TOKEN:
    print('Skipped - no IBM token')
else:
    # SF's get_noise_data — fetch noise from real hardware
    noise = ibm.get_noise_data(TARGET)
    nq_show = min(len(noise['t1']), 10)

    total_q = noise.get('num_qubits', len(noise['t1']))
    print(f'Target: {TARGET} ({total_q} total qubits)')
    print(f'\nLive noise characterization (first {nq_show} qubits):')
    print(f'{"Qubit":<6} {"T1 (us)":<12} {"T2 (us)":<12} {"Readout Err"}')
    print('-' * 42)
    for i in range(nq_show):
        t1 = noise['t1'][i] * 1e6 if noise['t1'][i] else 0
        t2 = noise['t2'][i] * 1e6 if noise['t2'][i] else 0
        ro = noise['readout_error'][i] if noise['readout_error'][i] else 0
        print(f'  {i:<4} {t1:<12.1f} {t2:<12.1f} {ro:.4f}')
# Out:
# qiskit_runtime_service.backends:WARNING:2026-06-12 03:09:29,941: Using instance: open-instance, plan: open
# Target: ibm_fez (156 total qubits)
#
# Live noise characterization (first 10 qubits):
# Qubit  T1 (us)      T2 (us)      Readout Err
# ------------------------------------------
#   0    55.9         58.5         0.0173
#   1    186.7        244.6        0.0181
#   2    258.7        176.9        0.0039
#   3    192.6        180.9        0.0208
#   4    207.6        143.8        0.0042
#   5    89.3         96.2         0.0078
#   6    179.8        144.1        0.0088
#   7    57.9         31.8         0.0168
#   8    164.1        58.9         0.0093
#   9    245.8        23.3         0.0068

# %% [markdown]
# ---
# ## 8. Submit Circuits to IBM QPU (SF-Native)
#
# SF's `IBMProvider.run()` handles everything — bridge, transpile, submit.
# You just pass your SF circuit. **Jobs are submitted instantly** (no waiting).

# %%
if not IBM_TOKEN:
    print('Skipped - no IBM token')
    submitted_jobs = {}
else:
    demo_circuits = [
        ('Bell-2q', bell),
        ('GHZ-3q', ghz),
        ('Grover-|11>', grover),
    ]

    submitted_jobs = {}  # name -> SF IBMJob

    for name, sf_circ in demo_circuits:
        print(f'\n--- {name} ---')
        print(f'  SF Circuit: {sf_circ.n_qubits}q, {sf_circ.gate_count} gates')
        print(sf_circ.draw())

        # One line: SF handles bridge + transpile + submit
        job = ibm.run(sf_circ, backend=TARGET, shots=4096)
        submitted_jobs[name] = job
        print(f'  Submitted! Job ID: {job.job_id}')
        print(f'  Status: {job.status}')

    print(f'\nAll {len(submitted_jobs)} jobs submitted via SF to {TARGET}.')
    print('Run the next cell to check status & fetch results.')
# Out:
# --- Bell-2q ---
#   SF Circuit: 2q, 2 gates
# q0: ─  [H]  ─   ●   ─
# q1: ─  ───  ─   ⊕   ─
# [06/12/26 03:09:31] INFO     Submitting to IBM Cloud (ibm_fez) via Superfermion-Native...             ]8;id=183841;file://C:\Users\ASUS\OneDrive\Desktop\superfermion\superfermion\utils\logging.py\logging.py]8;;\:]8;id=74516;file://C:\Users\ASUS\OneDrive\Desktop\superfermion\superfermion\utils\logging.py#55\55]8;;\
# qiskit_runtime_service.backends:WARNING:2026-06-12 03:09:31,027: Using instance: open-instance, plan: open
#   Submitted! Job ID: d8li84jqv2lc7386hbdg
#   Status: JobStatus.QUEUED
#
# --- GHZ-3q ---
#   SF Circuit: 3q, 3 gates
# q0: ─  [H]  ─   ●   ─  ───  ─
# q1: ─  ───  ─   ⊕   ─   ●   ─
# q2: ─  ───  ─  ───  ─   ⊕   ─
# [06/12/26 03:09:34] INFO     Submitting to IBM Cloud (ibm_fez) via Superfermion-Native...             ]8;id=671182;file://C:\Users\ASUS\OneDrive\Desktop\superfermion\superfermion\utils\logging.py\logging.py]8;;\:]8;id=592430;file://C:\Users\ASUS\OneDrive\Desktop\superfermion\superfermion\utils\logging.py#55\55]8;;\
# qiskit_runtime_service.backends:WARNING:2026-06-12 03:09:34,659: Using instance: open-instance, plan: open
#   Submitted! Job ID: d8li85g32u0s73fa0vig
#   Status: JobStatus.QUEUED
#
# --- Grover-|11> ---
#   SF Circuit: 2q, 12 gates
# q0: ─  [H]  ─  ───  ─   ●   ─  [H]  ─  ───  ─  [X]  ─  ───  ─   ●   ─  [X]  ─  ───  ─  [H]  ─  ───  ─
# q1: ─  ───  ─  [H]  ─   ●   ─  ───  ─  [H]  ─  ───  ─  [X]  ─   ●   ─  ───  ─  [X]  ─  ───  ─  [H]  ─
# [06/12/26 03:09:37] INFO     Submitting to IBM Cloud (ibm_fez) via Superfermion-Native...             ]8;id=187417;file://C:\Users\ASUS\OneDrive\Desktop\superfermion\superfermion\utils\logging.py\logging.py]8;;\:]8;id=388100;file://C:\Users\ASUS\OneDrive\Desktop\superfermion\superfermion\utils\logging.py#55\55]8;;\
# qiskit_runtime_service.backends:WARNING:2026-06-12 03:09:37,701: Using instance: open-instance, plan: open
#   Submitted! Job ID: d8li8632d42s73cbfamg
#   Status: JobStatus.QUEUED
#
# All 3 jobs submitted via SF to ibm_fez.
# Run the next cell to check status & fetch results.

# %% [markdown]
# ---
# ## 9. Fetch QPU Results
#
# Check each job's status. If completed, display the measurement results.
# **Re-run this cell** anytime to poll for new results.

# %%
if not submitted_jobs:
    print('No jobs to fetch. Submit circuits in Cell 8 first.')
else:
    results = {}
    for name, job in submitted_jobs.items():
        print(f'\n--- {name} (job: {job.job_id[:20]}...) ---')
        print(f'  Status: {job.status}')

        if job.status.name == 'COMPLETED':
            try:
                run_result = job.result()  # SF RunResult with .counts
                counts = run_result.counts
                total = sum(counts.values())
                print(f'  Results ({total} shots):')
                for bs, cnt in sorted(counts.items(), key=lambda x: -x[1]):
                    bar = chr(9608) * max(1, int(cnt / total * 40))
                    print(f'    |{bs}> : {cnt:5d} ({cnt/total*100:5.1f}%) {bar}')
                results[name] = {'job_id': job.job_id, 'counts': counts}
            except Exception as e:
                print(f'  Error fetching: {e}')
        else:
            print(f'  Still in queue. Re-run this cell in ~30s to check again.')

    # Save completed results
    if results:
        out = ROOT / 'notebooks' / 'ibm_qpu_results.json'
        with open(out, 'w') as f:
            json.dump(results, f, indent=2, default=str)
        print(f'\nResults saved to: {out}')
# Out:
# --- Bell-2q (job: d8li84jqv2lc7386hbdg...) ---
#   Status: JobStatus.FAILED
#   Still in queue. Re-run this cell in ~30s to check again.
#
# --- GHZ-3q (job: d8li85g32u0s73fa0vig...) ---
#   Status: JobStatus.FAILED
#   Still in queue. Re-run this cell in ~30s to check again.
#
# --- Grover-|11> (job: d8li8632d42s73cbfamg...) ---
#   Status: JobStatus.QUEUED
#   Still in queue. Re-run this cell in ~30s to check again.

# %% [markdown]
# ---
# ## 10. Error Handling & Diagnostics
#
# How SF handles errors — both from the API and from quantum hardware.

# %%
print('=== Error Handling Demo ===')
print()

# 1. Invalid qubit index
print('1. Invalid qubit index:')
try:
    bad = sf.Circuit(2)
    bad.h(5)  # qubit 5 does not exist in a 2-qubit circuit
except Exception as e:
    print(f'   Caught: {type(e).__name__}: {e}')

# 2. Parameterized circuit with symbolic params
print('\n2. Parameterized circuit (symbolic params):')
theta = sf.param('theta')
param_circ = sf.Circuit(1).ry(theta, 0)
print(f'   Circuit params: {param_circ.parameters}')
print(f'   Draw: {param_circ.draw()}')
bound = param_circ.bind({'theta': math.pi / 4})
r = sf.run(bound, backend='statevector', shots=1000)
print(f'   After binding theta=pi/4: {r.counts}')

# 3. Circuit serialization round-trip
print('\n3. JSON round-trip (save/load):')
bell_json = bell.to_json()
bell_loaded = sf.Circuit.from_json(bell_json)
print(f'   Original:  {bell}')
print(f'   Loaded:    {bell_loaded}')
print(f'   Match: {bell.n_qubits == bell_loaded.n_qubits and bell.gate_count == bell_loaded.gate_count}')
# Out:
# === Error Handling Demo ===
#
# 1. Invalid qubit index:
#    Caught: IndexError: Qubit 5 out of range for 2-qubit circuit in gate 'H'.
#   Valid range: 0 to 1
#   Fix: Use qubit indices in [0, 1]
#
# 2. Parameterized circuit (symbolic params):
#    Circuit params: ['theta']
#    Draw: q0: ─[RY(theta)]─
#    After binding theta=pi/4: {'0': 871, '1': 129}
#
# 3. JSON round-trip (save/load):
#    Original:  Circuit(n_qubits=2, depth=2, gates=2)
#    Loaded:    Circuit(n_qubits=2, depth=2, gates=2)
#    Match: True

# %% [markdown]
# ---
# ## 12. MPS Tensor Networks — Many-Qubit Scaling
#
# SF auto-routes circuits with >32 qubits to **MPS (Matrix Product State)** simulation.
# Memory stays linear in qubit count — no 2^N explosion.
# The **singularity** backend picks the best engine automatically.

# %%
# 50-qubit GHZ state — impossible for statevector (2^50 = 1 PB)
# MPS handles this with linear memory using bond-dimension truncation
n = 50
ghz_big = sf.Circuit(n)
ghz_big.h(0)
for i in range(n - 1):
    ghz_big.cx(i, i + 1)

print(f'Built {n}-qubit GHZ: {ghz_big.gate_count} gates')
print(f'Statevector would need: {2**n / 1e15:.1f} Petabytes')
print(f'MPS needs: ~{n * 64 * 2} bytes (linear in N)')

t0 = time.perf_counter()
r = sf.run(ghz_big, backend='singularity', shots=1024)
dt = (time.perf_counter() - t0) * 1000
print(f'\nSimulated in {dt:.0f} ms')
print(f'Backend: {r.metadata.get("backend", "auto")}  Regime: {r.metadata.get("regime", "auto")}')

top3 = sorted(r.counts.items(), key=lambda x: -x[1])[:3]
total = sum(r.counts.values())
print(f'\nTop measurement outcomes ({total} shots):')
for bs, cnt in top3:
    pct = cnt / total * 100
    bar = '#' * int(pct / 2)
    label = 'all-0' if all(c == '0' for c in bs) else 'all-1' if all(c == '1' for c in bs) else 'other'
    print(f'  |{bs[:8]}...> : {cnt:4d} ({pct:5.1f}%) [{label}] {bar}')
# Out:
# Built 50-qubit GHZ: 50 gates
# Statevector would need: 1.1 Petabytes
# MPS needs: ~6400 bytes (linear in N)
# Simulated in 1714 ms
# Backend: auto  Regime: auto
#
# Top measurement outcomes (1024 shots):
#   |00000000...> :  530 ( 51.8%) [all-0] #########################
#   |11111111...> :  494 ( 48.2%) [all-1] ########################

# %%
# GHZ scaling: 10, 20, 40 qubits — all MPS-safe
print('=== GHZ Scaling (MPS backend) ===')
print(f'{"Qubits":<8} {"Gates":<8} {"Time (ms)":<12} {"Top outcome"}')
print('-' * 55)

for n in [10, 20, 40]:
    ghz = sf.Circuit(n)
    ghz.h(0)
    for i in range(n - 1): ghz.cx(i, i + 1)
    t0 = time.perf_counter()
    r = sf.run(ghz, backend='singularity', shots=1024)
    dt = (time.perf_counter() - t0) * 1000
    top = sorted(r.counts.items(), key=lambda x: -x[1])[0]
    print(f'  {n:<6} {ghz.gate_count:<8} {dt:<12.1f} |{top[0][:8]}...>={top[1]}')
# Out:
# === GHZ Scaling (MPS backend) ===
# Qubits   Gates    Time (ms)    Top outcome
# -------------------------------------------------------
#   10     10       2.7          |00000000...>=515
#   20     20       236.4        |00000000...>=515
#   40     40       1635.5       |00000000...>=536

# %% [markdown]
# ---
# ## 13. Quantum Machine Learning — VQE & QAOA
#
# SF has built-in **VQE** and **QAOA** solvers with analytic parameter-shift gradients.
# Works on any backend. No PennyLane or Qiskit needed.

# %%
from superfermion.algorithms.variational import VQE, QAOA
from superfermion.observables.core import SparsePauliOp

# ── VQE: Find ground state of a 2-qubit Ising Hamiltonian ──
# H = -Z⊗Z - 0.5·X⊗I - 0.5·I⊗X  (exact ground state = -√2 ≈ -1.4142)
H = SparsePauliOp.from_dict({'ZZ': -1.0, 'XI': -0.5, 'IX': -0.5})
print(f'Hamiltonian: {len(H.terms)} Pauli terms')
print(f'  Terms: {[str(t) for t in H.terms]}')

# Build a variational ansatz: RY(θ₀)⊗RY(θ₁) → CNOT
ansatz = sf.Circuit(2)
ansatz.ry(sf.param('t0'), 0)
ansatz.ry(sf.param('t1'), 1)
ansatz.cx(0, 1)
print(f'\nAnsatz: {ansatz.n_qubits}q, {ansatz.gate_count} gates, {len(ansatz.parameters)} params')
print(ansatz.draw())
# Out:
# Hamiltonian: 3 Pauli terms
#   Terms: ["PauliString('ZZ', coeff=(-1+0j))", "PauliString('XI', coeff=(-0.5+0j))", "PauliString('IX', coeff=(-0.5+0j))"]
#
# Ansatz: 2q, 3 gates, 2 params
# q0: ─[RY(t0)]─  ───  ─   ●   ─
# q1: ─  ───  ─[RY(t1)]─   ⊕   ─

# %%
# Run VQE optimization
vqe = VQE(ansatz, H, backend='statevector', optimizer='COBYLA')

t0 = time.perf_counter()
vqe_result = vqe.minimize(iterations=50, seed=42)
dt = (time.perf_counter() - t0) * 1000

print(f'VQE Optimization:')
print(f'  Ground state energy: {vqe_result.optimal_value:+.6f} Ha')
print(f'  Exact (analytical):  -1.414214 Ha  (-√2)')
print(f'  Error:               {abs(vqe_result.optimal_value - (-math.sqrt(2))):.2e}')
print(f'  Optimizer iters:     {vqe_result.metadata.get("n_fun_evals", "?")}')
print(f'  Wall-clock time:     {dt:.0f} ms')
print(f'  Optimal params:      {vqe_result.optimal_params}')
# Out:
# VQE Optimization:
#   Ground state energy: -1.414214 Ha
#   Exact (analytical):  -1.414214 Ha  (-√2)
#   Error:               1.02e-09
#   Optimizer iters:     50
#   Wall-clock time:     167 ms
#   Optimal params:      {'t0': 1.5708697187047884, 't1': 0.7854081923527251}

# %%
# ── QAOA: MaxCut on a 4-node graph ──
# Graph: 5 edges forming a diamond + cross
edges = [(0,1), (1,2), (2,3), (3,0), (0,2)]
print(f'MaxCut graph: 4 nodes, {len(edges)} edges')
print(f'  Edges: {edges}')
print(f'  Max cut value: 4 (cut all 5 edges is impossible, 4 is optimal)')

qaoa = QAOA(4, edges, p_layers=2, backend='statevector')

t0 = time.perf_counter()
qaoa_result = qaoa.minimize(iterations=40, seed=42)
dt = (time.perf_counter() - t0) * 1000

print(f'\nQAOA Optimization (p=2):')
print(f'  Cost value:       {qaoa_result.optimal_value:.4f}')
print(f'  Wall-clock time:  {dt:.0f} ms')
print(f'  Scipy converged:  {qaoa_result.metadata.get("scipy_success", "?")}')
# Out:
# MaxCut graph: 4 nodes, 5 edges
#   Edges: [(0, 1), (1, 2), (2, 3), (3, 0), (0, 2)]
#   Max cut value: 4 (cut all 5 edges is impossible, 4 is optimal)
# QAOA Optimization (p=2):
#   Cost value:       3.7084
#   Wall-clock time:  609 ms
#   Scipy converged:  True

# %% [markdown]
# ---
# ## 14. Adjoint Gradients — O(1) Differentiation
#
# SF's **adjoint method** computes the full gradient in 1 forward + 1 backward pass.
# That's 15-48× faster than parameter-shift (which needs 2P evaluations for P params).

# %%
from superfermion.qml.gradient.adjoint import adjoint_grad_vector

# Build a 3-qubit parametric circuit
grad_circ = sf.Circuit(3)
grad_circ.ry(sf.param('a'), 0)
grad_circ.ry(sf.param('b'), 1)
grad_circ.ry(sf.param('c'), 2)
grad_circ.cx(0, 1)
grad_circ.cx(1, 2)

print('Circuit:')
print(grad_circ.draw())

# Observable: <ZZI + 0.5·IZZ>
obs = SparsePauliOp.from_dict({'ZZI': 1.0, 'IZZ': 0.5})
params = np.array([0.3, 0.7, 1.2])

# Compute gradient — 1 forward + 1 backward = full gradient vector
t0 = time.perf_counter()
grad = adjoint_grad_vector(grad_circ, obs, ['a', 'b', 'c'], params)
dt = (time.perf_counter() - t0) * 1000

print(f'\nAdjoint gradient (params = {params}):')
for name, g in zip(['a', 'b', 'c'], grad):
    print(f'  d<O>/d{name} = {g:+.8f}')
print(f'\nComputed in {dt:.2f} ms (1 forward + 1 backward pass)')
print(f'Scales as O(gates × 2^n), independent of parameter count!')
# Out:
# Circuit:
# q0: ─[RY(a)]─  ───  ─  ───  ─   ●   ─  ───  ─
# q1: ─  ───  ─[RY(b)]─  ───  ─   ⊕   ─   ●   ─
# q2: ─  ───  ─  ───  ─[RY(c)]─  ───  ─   ⊕   ─
#
# Adjoint gradient (params = [0.3 0.7 1.2]):
#   d<O>/da = -0.00000000
#   d<O>/db = -0.64421769
#   d<O>/dc = -0.46601954
#
# Computed in 2.08 ms (1 forward + 1 backward pass)
# Scales as O(gates × 2^n), independent of parameter count!

# %% [markdown]
# ---
# ## 15. Quantum Error Correction — Research Codes
#
# SF includes QEC codes from repetition codes to surface codes.
# Build, encode, and simulate error-corrected circuits natively.

# %%
from superfermion.qec.codes.linear import RepetitionCode, ShorCode, SteaneCode
from superfermion.qec.codes.surface import SurfaceCode

print('=== QEC Code Registry ===')
print(f'{"Code":<20} {"Notation":<12} {"Qubits":<8} {"Gates":<8} {"Type"}')
print('-' * 65)

# 1. Repetition code [[3,1,1]] — simplest bit-flip code
rep = RepetitionCode(n=3, code_type='bit')
rep_circ = rep.build()
r = sf.run(rep_circ, backend='statevector', shots=1000)
top = sorted(r.counts.items(), key=lambda x: -x[1])[0]
print(f'  {"Repetition":<18} [[3,1,1]]    {rep_circ.n_qubits:<8} {rep_circ.gate_count:<8} bit-flip')
print(f'    Encoded |000>: syndrome={top[0]} (all-0 = no error)')

# 2. Shor code [[9,1,3]] — corrects any single-qubit error
shor = ShorCode()
shor_circ = shor.build()
print(f'  {"Shor":<18} [[9,1,3]]    {shor_circ.n_qubits:<8} {shor_circ.gate_count:<8} full 1q')

# 3. Steane code [[7,1,3]] — CSS code, corrects any 1q error
steane = SteaneCode()
steane_circ = steane.build()
r = sf.run(steane_circ, backend='statevector', shots=0)
sv = np.asarray(r.statevector, dtype=np.complex128)
n_states = sum(1 for a in sv if abs(a)**2 > 0.01)
print(f'  {"Steane":<18} [[7,1,3]]    {steane_circ.n_qubits:<8} {steane_circ.gate_count:<8} CSS')
print(f'    Encoded state: {n_states} basis states with |amp|² > 0.01')

# 4. Surface code d=3 — most practical QEC code
sc = SurfaceCode(distance=3)
sc_circ = sc.build_syndrome_extraction()
print(f'  {"Surface d=3":<18} [[9,1,3]]    {sc_circ.n_qubits:<8} {sc_circ.gate_count:<8} topological')
print(f'    {sc.n_data} data + {sc.n_measure} ancilla qubits for 1 round of syndrome extraction')
# Out:
# === QEC Code Registry ===
# Code                 Notation     Qubits   Gates    Type
# -----------------------------------------------------------------
#   Repetition         [[3,1,1]]    5        8        bit-flip
#     Encoded |000>: syndrome=00000 (all-0 = no error)
#   Shor               [[9,1,3]]    9        11       full 1q
#   Steane             [[7,1,3]]    7        12       CSS
#     Encoded state: 8 basis states with |amp|² > 0.01
#   Surface d=3        [[9,1,3]]    17       48       topological
#     9 data + 8 ancilla qubits for 1 round of syndrome extraction

# %%
# Simulate Steane code — show the encoded logical state
print('=== Steane [[7,1,3]] — Encoded Logical |0⟩ ===')
print(f'Circuit: {steane_circ.n_qubits} qubits, {steane_circ.gate_count} gates')
print(steane_circ.draw())

r = sf.run(steane_circ, backend='statevector', shots=0)
sv = np.asarray(r.statevector, dtype=np.complex128)
print(f'\nEncoded statevector (|amplitude|² > 0.01):')
for i in range(len(sv)):
    prob = abs(sv[i])**2
    if prob > 0.01:
        bs = format(i, f'0{steane_circ.n_qubits}b')
        print(f'  |{bs}⟩ : amp={sv[i]:.4f}, prob={prob:.4f}')
# Out:
# === Steane [[7,1,3]] — Encoded Logical |0⟩ ===
# Circuit: 7 qubits, 12 gates
# q0: ─  [H]  ─  ───  ─  ───  ─   ●   ─   ●   ─   ●   ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─
# q1: ─  ───  ─  [H]  ─  ───  ─   │   ─   │   ─   │   ─   ●   ─   ●   ─   ●   ─  ───  ─  ───  ─  ───  ─
# q2: ─  ───  ─  ───  ─  ───  ─   ⊕   ─   │   ─   │   ─   ⊕   ─   │   ─   │   ─  ───  ─  ───  ─  ───  ─
# q3: ─  ───  ─  ───  ─  [H]  ─  ───  ─   │   ─   │   ─  ───  ─   │   ─   │   ─   ●   ─   ●   ─   ●   ─
# q4: ─  ───  ─  ───  ─  ───  ─  ───  ─   ⊕   ─   │   ─  ───  ─   │   ─   │   ─   ⊕   ─   │   ─   │   ─
# q5: ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─   │   ─  ───  ─   ⊕   ─   │   ─  ───  ─   ⊕   ─   │   ─
# q6: ─  ───  ─  ───  ─  ───  ─  ───  ─  ───  ─   ⊕   ─  ───  ─  ───  ─   ⊕   ─  ───  ─  ───  ─   ⊕   ─
#
# Encoded statevector (|amplitude|² > 0.01):
#   |0000000⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |0001111⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |0110011⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |0111100⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |1010101⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |1011010⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |1100110⟩ : amp=0.3536+0.0000j, prob=0.1250
#   |1101001⟩ : amp=0.3536+0.0000j, prob=0.1250

# %% [markdown]
# ---
# ## 16. Benchpress Benchmarks — SF vs Qiskit (Live Pytest)
#
# **IBM Benchpress** test suite, executed live via `subprocess.run`.
#
# Runs the actual pytest tests from `tests/benchpress/`:
# - **16a**: Accuracy — statevector fidelity vs Qiskit ground truth (42 tests)
# - **16b**: Latency — circuit construction, simulation, Clifford timing
# - **16c**: Memory — peak memory tracking via tracemalloc
# - **16d**: Manipulation — Pauli twirling, gate cancellation, basis change
# - **16e**: Full Suite — all benchpress tests at once
#
# All tests use `--benchmark-disable` for fast execution with PASS/FAIL output.

# %%
import subprocess, sys, os
from pathlib import Path

# Resolve ROOT independently (works even if cell run standalone)
_cwd = Path.cwd()
BENCH_ROOT = _cwd.parent if 'notebooks' in str(_cwd) else _cwd

# Helper to run pytest with nice output
def run_pytest(test_path, extra_args=None, timeout=300, benchmark_enable=False):
    args = [sys.executable, '-m', 'pytest', test_path, '-v', '--tb=short', '--no-header']
    if benchmark_enable:
        # Enable benchmark metrics (ms/MB) with minimal overhead
        args.extend(['--benchmark-enable', '--benchmark-min-rounds=1', '--benchmark-warmup=off'])
    else:
        args.append('--benchmark-disable')
    if extra_args:
        args.extend(extra_args)
    result = subprocess.run(args, cwd=str(BENCH_ROOT), capture_output=True, text=True, timeout=timeout)
    # Show stdout, stderr only if failure
    print(result.stdout)
    if result.returncode != 0 and result.stderr:
        print('\n--- STDERR ---')
        print(result.stderr[-2000:])
    return result.returncode

print('Runners ready. Execute each cell below to see live benchpress results.')
# Out:
# Runners ready. Execute each cell below to see live benchpress results.

# %%
# ── 16a. ACCURACY — Statevector Fidelity vs Qiskit Ground Truth ──
# 42 tests: GHZ, QFT, QV, Clifford, MCX, QASM2 import, gate matrices, expectation values
print('=' * 70)
print('  BENCHPRESS: SCIENTIFIC ACCURACY (fidelity > 0.9999)')
print('  SF simulator / rust / jax    vs    Qiskit Aer statevector')
print('=' * 70)
print()
rc = run_pytest('tests/benchpress/test_accuracy.py')
print()
print(f'Accuracy suite exit code: {rc}  (0 = all passed)')
# Out:
# Runners ready. Execute each cell below to see live benchpress results.
# ======================================================================
#   BENCHPRESS: SCIENTIFIC ACCURACY (fidelity > 0.9999)
#   SF simulator / rust / jax    vs    Qiskit Aer statevector
# ======================================================================
#
# ============================= test session starts =============================
# collecting ... collected 42 items
#
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[4-simulator] PASSED [  2%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[4-rust] PASSED [  4%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[4-jax] PASSED [  7%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[8-simulator] PASSED [  9%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[8-rust] PASSED [ 11%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[8-jax] PASSED [ 14%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[12-simulator] PASSED [ 16%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[12-rust] PASSED [ 19%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[12-jax] PASSED [ 21%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[4-simulator] PASSED [ 23%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[4-rust] PASSED [ 26%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[4-jax] PASSED [ 28%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[8-simulator] PASSED [ 30%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[8-rust] PASSED [ 33%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[8-jax] PASSED [ 35%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[12-simulator] PASSED [ 38%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[12-rust] PASSED [ 40%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[12-jax] PASSED [ 42%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[10-simulator] PASSED [ 45%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[10-rust] PASSED [ 47%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[10-jax] PASSED [ 50%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[20-simulator] PASSED [ 52%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[20-rust] PASSED [ 54%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[20-jax] PASSED [ 57%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_gate_matrix_definitions PASSED [ 59%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_expectation_value_accuracy[simulator] PASSED [ 61%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_expectation_value_accuracy[rust] PASSED [ 64%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_expectation_value_accuracy[jax] PASSED [ 66%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[4-simulator] PASSED [ 69%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[4-rust] PASSED [ 71%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[4-jax] PASSED [ 73%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[8-simulator] PASSED [ 76%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[8-rust] PASSED [ 78%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[8-jax] PASSED [ 80%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_multi_control_fidelity[simulator] PASSED [ 83%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_multi_control_fidelity[rust] PASSED [ 85%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_multi_control_fidelity[jax] PASSED [ 88%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qasm2_import_fidelity[simulator] PASSED [ 90%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qasm2_import_fidelity[rust] PASSED [ 92%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qasm2_import_fidelity[jax] PASSED [ 95%]
# tests/benchpress/test_accuracy.py::TestBigIntQASM2::test_bigint_qasm2_parsing PASSED [ 97%]
# tests/benchpress/test_accuracy.py::TestBigIntQASM2::test_bigint_qasm2_equivalence PASSED [100%]
#
# ============================== warnings summary ===============================
# tests/benchpress/test_accuracy.py: 68 warnings
#   C:\Users\ASUS\OneDrive\Desktop\superfermion\.custom_venv\Lib\site-packages\stevedore\extension.py:340: DeprecationWarning: Since backends now support running jobs that contain both fractional gates and dynamic circuit, IBMFractionalTranslationPlugin is deprecated as of qiskit-ibm-runtime 0.42.0 and will be removed no sooner than 3 months after the release date. Use IBMDynamicFractionalTranslationPlugin instead.
#     obj = plugin(*invoke_args, **invoke_kwds)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ====================== 42 passed, 68 warnings in 35.23s =======================
#
#
# Accuracy suite exit code: 0  (0 = all passed)

# %%
# ── 16b. LATENCY — Circuit Construction + Simulation + Clifford ──
# Covers: QV100, DTC100, GHZ(10-200), QFT(10-50), EfficientSU2, param bind,
#         Clifford build/sim, multi-control, QASM export/import
print('=' * 70)
print('  BENCHPRESS: LATENCY (circuit build + simulate + manipulate)')
print('  SF vs Qiskit — same circuits, same seed, wall-clock timing')
print('=' * 70)
print()
# Skip the heaviest tests to keep runtime reasonable for a live demo
rc = run_pytest('tests/benchpress/test_latency.py',
    extra_args=['-k', 'not CliffordSimulationLatency and not ScalingLatency'],
    benchmark_enable=True)
print()
print(f'Latency suite exit code: {rc}  (0 = all passed)')
# Out:
# Runners ready. Execute each cell below to see live benchpress results.
# ======================================================================
#   BENCHPRESS: LATENCY (circuit build + simulate + manipulate)
#   SF vs Qiskit — same circuits, same seed, wall-clock timing
# ======================================================================
#
# ============================= test session starts =============================
# collecting ... collected 116 items / 29 deselected / 87 selected
#
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_build_sf PASSED [  1%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_build_qiskit PASSED [  2%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_DTC100_build_sf PASSED [  3%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_DTC100_build_qiskit PASSED [  4%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[10] PASSED [  5%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[50] PASSED [  6%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[100] PASSED [  8%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[200] PASSED [  9%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[10] PASSED [ 10%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[50] PASSED [ 11%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[100] PASSED [ 12%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[200] PASSED [ 13%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_sf[10] PASSED [ 14%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_sf[20] PASSED [ 16%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_sf[50] PASSED [ 17%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_qiskit[10] PASSED [ 18%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_qiskit[20] PASSED [ 19%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_qiskit[50] PASSED [ 20%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_paramSU2_100_build_sf PASSED [ 21%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_paramSU2_100_build_qiskit PASSED [ 22%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_param_bind_sf PASSED [ 24%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_param_bind_qiskit PASSED [ 25%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_clifford_build_sf PASSED [ 26%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_clifford_build_qiskit PASSED [ 27%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_multi_control_build_sf PASSED [ 28%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_multi_control_build_qiskit PASSED [ 29%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_qasm2_import_sf PASSED [ 31%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_qasm2_import_qiskit PASSED [ 32%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_bell_sim_sf[simulator] PASSED [ 33%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_bell_sim_sf[rust] PASSED [ 34%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_bell_sim_sf[jax] PASSED [ 35%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_bell_sim_qiskit PASSED [ 36%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[5-simulator] PASSED [ 37%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[5-rust] PASSED [ 39%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[5-jax] PASSED [ 40%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[10-simulator] PASSED [ 41%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[10-rust] PASSED [ 42%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[10-jax] PASSED [ 43%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[15-simulator] PASSED [ 44%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[15-rust] PASSED [ 45%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[15-jax] PASSED [ 47%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[20-simulator] PASSED [ 48%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[20-rust] PASSED [ 49%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_sf[20-jax] PASSED [ 50%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_qiskit[5] PASSED [ 51%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_qiskit[10] PASSED [ 52%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_qiskit[15] PASSED [ 54%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_GHZ_sim_qiskit[20] PASSED [ 55%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[4-simulator] PASSED [ 56%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[4-rust] PASSED [ 57%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[4-jax] PASSED [ 58%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[8-simulator] PASSED [ 59%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[8-rust] PASSED [ 60%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[8-jax] PASSED [ 62%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[12-simulator] PASSED [ 63%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[12-rust] PASSED [ 64%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[12-jax] PASSED [ 65%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[16-simulator] PASSED [ 66%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[16-rust] PASSED [ 67%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_sf[16-jax] PASSED [ 68%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_qiskit[4] PASSED [ 70%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_qiskit[8] PASSED [ 71%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_qiskit[12] PASSED [ 72%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_QFT_sim_qiskit[16] PASSED [ 73%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[10-simulator] PASSED [ 74%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[10-rust] PASSED [ 75%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[10-jax] PASSED [ 77%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[50-simulator] PASSED [ 78%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[50-rust] PASSED [ 79%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[50-jax] PASSED [ 80%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[100-simulator] PASSED [ 81%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[100-rust] PASSED [ 82%]
# tests/benchpress/test_latency.py::TestSimulationLatency::test_depth_scaling_10q_sf[100-jax] PASSED [ 83%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_sf[10] PASSED [ 85%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_sf[50] PASSED [ 86%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_sf[100] PASSED [ 87%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_qiskit[10] PASSED [ 88%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_qiskit[50] PASSED [ 89%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_qiskit[100] PASSED [ 90%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_DTC100_twirling_sf PASSED [ 91%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_DTC100_twirling_qiskit PASSED [ 93%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_multi_control_decompose_sf PASSED [ 94%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_multi_control_decompose_qiskit PASSED [ 95%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_QV100_basis_change_sf PASSED [ 96%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_QV100_basis_change_qiskit PASSED [ 97%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_random_clifford_decompose_sf PASSED [ 98%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_random_clifford_decompose_qiskit PASSED [100%]
#
# ============================== warnings summary ===============================
# tests/benchpress/test_latency.py: 158 warnings
#   C:\Users\ASUS\OneDrive\Desktop\superfermion\.custom_venv\Lib\site-packages\stevedore\extension.py:340: DeprecationWarning: Since backends now support running jobs that contain both fractional gates and dynamic circuit, IBMFractionalTranslationPlugin is deprecated as of qiskit-ibm-runtime 0.42.0 and will be removed no sooner than 3 months after the release date. Use IBMDynamicFractionalTranslationPlugin instead.
#     obj = plugin(*invoke_args, **invoke_kwds)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
#
# -------------------------------------------------------------------------------------------------------------------- benchmark: 87 tests --------------------------------------------------------------------------------------------------------------------
# Name (time in us)                                        Min                        Max                       Mean                  StdDev                     Median                     IQR            Outliers           OPS            Rounds  Iterations
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# test_qasm_export_sf[10]                               7.6000 (1.0)             170.1000 (1.0)               8.8129 (1.0)            2.8943 (inf)               8.4000 (1.0)            0.6000 (inf)     1367;1637  113,469.3892 (1.0)       27028           1
# test_GHZ_build_sf[10]                                14.4000 (1.89)         13,319.1000 (78.30)            16.4396 (1.87)          75.7375 (inf)              14.9000 (1.77)           0.3000 (inf)       13;4378   60,828.7565 (0.54)      30960           1
# test_qasm_export_sf[50]                              31.9000 (4.20)         11,124.9000 (65.40)            39.1320 (4.44)          93.3156 (inf)              34.4000 (4.10)           2.3000 (inf)       37;2876   25,554.5232 (0.23)      19881           1
# test_qasm_export_sf[100]                             61.8000 (8.13)         15,335.4000 (90.16)            71.4494 (8.11)         144.0542 (inf)              64.7000 (7.70)           3.6000 (inf)       14;1634   13,995.9205 (0.12)      12407           1
# test_GHZ_build_sf[50]                                71.9000 (9.46)         14,780.3000 (86.89)            86.9220 (9.86)         180.4121 (inf)              73.9000 (8.80)           4.3000 (inf)        8;1386   11,504.5728 (0.10)       7300           1
# test_GHZ_build_qiskit[10]                            78.4000 (10.32)        14,055.3000 (82.63)           107.9347 (12.25)        302.9332 (inf)              85.0000 (10.12)          9.8000 (inf)        22;787    9,264.8646 (0.08)       4902           1
# test_QFT_build_sf[10]                                97.7000 (12.86)           447.7000 (2.63)            119.5067 (13.56)         31.5221 (inf)             108.3000 (12.89)         11.7750 (inf)       743;836    8,367.7349 (0.07)       5531           1
# test_GHZ_build_sf[100]                              143.4000 (18.87)        15,384.9000 (90.45)           169.7932 (19.27)        294.0532 (inf)             150.7000 (17.94)          6.7000 (inf)         5;833    5,889.5187 (0.05)       5264           1
# test_qasm_export_qiskit[10]                         232.7000 (30.62)         8,630.6000 (50.74)           274.2763 (31.12)        235.5535 (inf)             243.7000 (29.01)         21.1750 (inf)         9;271    3,645.9581 (0.03)       1859           1
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Legend:
#   Outliers: 1 Standard Deviation from Mean; 1.5 IQR (InterQuartile Range) from 1st Quartile and 3rd Quartile.
#   OPS: Operations Per Second, computed as 1 / Mean
# ========= 87 passed, 29 deselected, 158 warnings in 247.24s (0:04:07) =========
#
#
# Latency suite exit code: 0  (0 = all passed)

# %%
# ── 16c. MEMORY — Peak Memory Tracking via tracemalloc ──
# Covers: circuit construction memory, simulation memory, object sizes,
#         parameter binding, manipulation memory
print('=' * 70)
print('  BENCHPRESS: MEMORY EFFICIENCY (tracemalloc peak MB)')
print('  SF vs Qiskit — same circuits, measure peak allocation')
print('=' * 70)
print()
# Skip simulation memory tests to keep runtime manageable
rc = run_pytest('tests/benchpress/test_memory.py',
    extra_args=['-k', 'not SimulationMemory and not ScalingMemory'],
    benchmark_enable=True)
print()
print(f'Memory suite exit code: {rc}  (0 = all passed)')
# Out:
# Runners ready. Execute each cell below to see live benchpress results.
# ======================================================================
#   BENCHPRESS: MEMORY EFFICIENCY (tracemalloc peak MB)
#   SF vs Qiskit — same circuits, measure peak allocation
# ======================================================================
#
# ============================= test session starts =============================
# collecting ... collected 72 items / 40 deselected / 32 selected
#
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_QV100_memory_sf PASSED [  3%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_QV100_memory_qiskit PASSED [  6%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_GHZ200_memory_sf PASSED [  9%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_GHZ200_memory_qiskit PASSED [ 12%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_DTC100_memory_sf PASSED [ 15%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_paramSU2_memory_sf PASSED [ 18%]
# tests/benchpress/test_memory.py::TestParameterBindingMemory::test_param_bind_memory_sf PASSED [ 21%]
# tests/benchpress/test_memory.py::TestParameterBindingMemory::test_param_bind_memory_qiskit PASSED [ 25%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[10] PASSED [ 28%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[50] PASSED [ 31%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[100] PASSED [ 34%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[200] PASSED [ 37%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[500] PASSED [ 40%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[10] PASSED [ 43%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[50] PASSED [ 46%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[100] PASSED [ 50%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[200] PASSED [ 53%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[500] PASSED [ 56%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_DTC100_twirling_memory_sf PASSED [ 59%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_DTC100_twirling_memory_qiskit PASSED [ 62%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_multi_control_decompose_memory_sf PASSED [ 65%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_multi_control_decompose_memory_qiskit PASSED [ 68%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_QV100_basis_change_memory_sf PASSED [ 71%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_QV100_basis_change_memory_qiskit PASSED [ 75%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_clifford_decompose_memory_sf PASSED [ 78%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_clifford_decompose_memory_qiskit PASSED [ 81%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_clifford_build_memory_sf PASSED [ 84%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_clifford_build_memory_qiskit PASSED [ 87%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_multi_control_build_memory_sf PASSED [ 90%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_multi_control_build_memory_qiskit PASSED [ 93%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_QV100_qasm2_import_memory_sf PASSED [ 96%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_QV100_qasm2_import_memory_qiskit PASSED [100%]
#
# ============================== warnings summary ===============================
# tests/benchpress/test_memory.py: 18 warnings
#   C:\Users\ASUS\OneDrive\Desktop\superfermion\.custom_venv\Lib\site-packages\stevedore\extension.py:340: DeprecationWarning: Since backends now support running jobs that contain both fractional gates and dynamic circuit, IBMFractionalTranslationPlugin is deprecated as of qiskit-ibm-runtime 0.42.0 and will be removed no sooner than 3 months after the release date. Use IBMDynamicFractionalTranslationPlugin instead.
#     obj = plugin(*invoke_args, **invoke_kwds)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
#
# ------------------------------------------------------------------------------------------------------- benchmark: 22 tests -------------------------------------------------------------------------------------------------------
# Name (time in ms)                                      Min                    Max                   Mean              StdDev                 Median                 IQR            Outliers       OPS            Rounds  Iterations
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# test_GHZ200_memory_sf                               2.2308 (1.0)          23.7647 (1.56)          3.4454 (1.07)       2.1192 (inf)           2.6386 (1.0)        1.1723 (inf)         34;43  290.2425 (0.94)        387           1
# test_multi_control_build_memory_sf                  2.3586 (1.06)         15.8484 (1.04)          3.2301 (1.0)        1.1237 (inf)           2.9391 (1.11)       0.9008 (inf)         22;11  309.5858 (1.0)         261           1
# test_clifford_decompose_memory_qiskit               2.3800 (1.07)         29.6842 (1.94)          4.5731 (1.42)       3.2055 (inf)           3.6343 (1.38)       1.9134 (inf)         10;10  218.6722 (0.71)        210           1
# test_param_bind_memory_qiskit                       2.5695 (1.15)         18.7018 (1.22)          3.6072 (1.12)       1.6215 (inf)           3.3146 (1.26)       0.7884 (inf)           5;9  277.2235 (0.90)        181           1
# test_QV100_memory_qiskit                            2.9476 (1.32)         15.2730 (1.0)           4.1688 (1.29)       1.1363 (inf)           4.0332 (1.53)       0.9962 (inf)          10;1  239.8756 (0.77)        143           1
# test_multi_control_build_memory_qiskit              3.2184 (1.44)         19.3411 (1.27)          4.4679 (1.38)       1.8033 (inf)           3.8623 (1.46)       1.5959 (inf)          17;2  223.8213 (0.72)        197           1
# test_GHZ200_memory_qiskit                           6.6941 (3.00)         23.8189 (1.56)          7.6106 (2.36)       1.8820 (inf)           7.2194 (2.74)       0.5192 (inf)          5;10  131.3962 (0.42)        104           1
# test_param_bind_memory_sf                          14.0361 (6.29)         29.7582 (1.95)         16.8719 (5.22)       3.1270 (inf)          15.8373 (6.00)       1.1054 (inf)          7;10   59.2701 (0.19)         54           1
# test_multi_control_decompose_memory_sf             15.9867 (7.17)         32.8166 (2.15)         17.9106 (5.54)       3.4650 (inf)          16.9577 (6.43)       1.1208 (inf)           3;4   55.8327 (0.18)         43           1
# test_DTC100_twirling_memory_qiskit                 20.6147 (9.24)         79.8481 (5.23)         31.8296 (9.85)      13.5163 (inf)          25.2809 (9.58)      14.1255 (inf)           6;1   31.4173 (0.10)         40           1
# test_paramSU2_memory_sf                            28.3782 (12.72)        51.3908 (3.36)         32.1462 (9.95)       4.4834 (inf)          30.7473 (11.65)      3.9032 (inf)           1;1   31.1079 (0.10)         27           1
# test_multi_control_decompose_memory_qiskit        125.9545 (56.46)       162.5027 (10.64)       136.9547 (42.40)     12.7423 (inf)         131.2337 (49.74)     13.4055 (inf)           1;1    7.3017 (0.02)          7           1
# test_clifford_decompose_memory_sf                 390.0661 (174.85)      414.7277 (27.15)       403.5188 (124.92)    12.4830 (inf)         405.7626 (153.78)    18.4962 (inf)           1;0    2.4782 (0.01)          3           1
# test_QV100_basis_change_memory_qiskit             412.2075 (184.78)      615.6900 (40.31)       510.5151 (158.05)   101.9149 (inf)         503.6479 (190.88)   152.6119 (inf)           1;0    1.9588 (0.01)          3           1
# test_DTC100_twirling_memory_sf                    492.9967 (221.00)      805.2956 (52.73)       599.6602 (185.65)   178.1270 (inf)         500.6883 (189.76)   234.2242 (inf)           1;0    1.6676 (0.01)          3           1
# test_DTC100_memory_sf                             619.6433 (277.77)      643.7370 (42.15)       631.6901 (195.56)    17.0368 (inf)         631.6901 (239.40)    24.0937 (inf)           0;0    1.5831 (0.01)          2           1
# test_QV100_memory_sf                              696.1269 (312.05)      905.3874 (59.28)       800.7572 (247.90)   147.9695 (inf)         800.7572 (303.48)   209.2605 (inf)           0;0    1.2488 (0.00)          2           1
# test_clifford_build_memory_sf                   2,567.1836 (>1000.0)   2,567.1836 (168.09)    2,567.1836 (794.76)     0.0000 (1.0)       2,567.1836 (972.93)     0.0000 (1.0)           0;0    0.3895 (0.00)          1           1
# test_QV100_qasm2_import_memory_qiskit           3,669.9637 (>1000.0)   3,669.9637 (240.29)    3,669.9637 (>1000.0)    0.0000 (1.0)       3,669.9637 (>1000.0)    0.0000 (1.0)           0;0    0.2725 (0.00)          1           1
# test_QV100_basis_change_memory_sf              10,413.6924 (>1000.0)  10,413.6924 (681.84)   10,413.6924 (>1000.0)    0.0000 (1.0)      10,413.6924 (>1000.0)    0.0000 (1.0)           0;0    0.0960 (0.00)          1           1
# test_QV100_qasm2_import_memory_sf              13,100.1475 (>1000.0)  13,100.1475 (857.73)   13,100.1475 (>1000.0)    0.0000 (1.0)      13,100.1475 (>1000.0)    0.0000 (1.0)           0;0    0.0763 (0.00)          1           1
# test_clifford_build_memory_qiskit              24,866.5684 (>1000.0)  24,866.5684 (>1000.0)  24,866.5684 (>1000.0)    0.0000 (1.0)      24,866.5684 (>1000.0)    0.0000 (1.0)           0;0    0.0402 (0.00)          1           1
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Legend:
#   Outliers: 1 Standard Deviation from Mean; 1.5 IQR (InterQuartile Range) from 1st Quartile and 3rd Quartile.
#   OPS: Operations Per Second, computed as 1 / Mean
# ========= 32 passed, 40 deselected, 18 warnings in 250.21s (0:04:10) ==========
#
#
# Memory suite exit code: 0  (0 = all passed)

# %%
# ── 16d. MANIPULATION — Pauli Twirling, Gate Cancellation, Basis Change ──
# Covers: Pauli twirling, rotation merging, constant folding, Clifford decompose,
#         basis translation, MCX decompose, swap optimization
print('=' * 70)
print('  BENCHPRESS: CIRCUIT MANIPULATION')
print('  Compiler passes — twirling, cancellation, merging, basis change')
print('=' * 70)
print()
rc = run_pytest('tests/benchpress/test_manipulation.py',
    benchmark_enable=True)
print()
print(f'Manipulation suite exit code: {rc}  (0 = all passed)')
# Out:
# Runners ready. Execute each cell below to see live benchpress results.
# ======================================================================
#   BENCHPRESS: CIRCUIT MANIPULATION
#   Compiler passes — twirling, cancellation, merging, basis change
# ======================================================================
#
# ============================= test session starts =============================
# collecting ... collected 101 items
#
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_sf[4] PASSED [  0%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_sf[8] PASSED [  1%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_sf[16] PASSED [  2%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_fidelity PASSED [  3%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_dynamical_decoupling_sf[4] PASSED [  4%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_dynamical_decoupling_sf[8] PASSED [  5%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_dynamical_decoupling_sf[16] PASSED [  6%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_qiskit[4] SKIPPED [  7%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_qiskit[8] SKIPPED [  8%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_qiskit[16] SKIPPED [  9%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[4] PASSED [ 10%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[8] PASSED [ 11%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[16] PASSED [ 12%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[32] PASSED [ 13%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[4] PASSED [ 14%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[8] PASSED [ 15%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[16] PASSED [ 16%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[32] PASSED [ 17%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[4] PASSED [ 18%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[8] PASSED [ 19%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[16] PASSED [ 20%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[32] PASSED [ 21%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[4] PASSED [ 22%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[8] PASSED [ 23%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[16] PASSED [ 24%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[32] PASSED [ 25%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_sf[4] PASSED [ 26%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_sf[8] PASSED [ 27%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_sf[16] PASSED [ 28%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_qiskit[4] PASSED [ 29%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_qiskit[8] PASSED [ 30%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_qiskit[16] PASSED [ 31%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[10] PASSED [ 32%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[50] PASSED [ 33%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[100] PASSED [ 34%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[500] PASSED [ 35%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[10] PASSED [ 36%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[50] PASSED [ 37%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[100] PASSED [ 38%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[500] PASSED [ 39%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[8] PASSED [ 40%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[16] PASSED [ 41%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[32] PASSED [ 42%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[64] PASSED [ 43%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[8] PASSED [ 44%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[16] PASSED [ 45%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[32] PASSED [ 46%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[64] PASSED [ 47%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_sf[4] PASSED [ 48%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_sf[8] PASSED [ 49%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_sf[16] PASSED [ 50%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_qiskit[4] PASSED [ 51%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_qiskit[8] PASSED [ 52%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_qiskit[16] PASSED [ 53%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[4-0] PASSED [ 54%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[4-1] PASSED [ 55%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[4-2] PASSED [ 56%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[8-0] PASSED [ 57%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[8-1] PASSED [ 58%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[8-2] PASSED [ 59%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[16-0] PASSED [ 60%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[16-1] PASSED [ 61%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[16-2] PASSED [ 62%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-0] PASSED [ 63%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-1] PASSED [ 64%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-2] PASSED [ 65%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-3] PASSED [ 66%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-0] PASSED [ 67%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-1] PASSED [ 68%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-2] PASSED [ 69%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-3] PASSED [ 70%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-0] PASSED [ 71%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-1] PASSED [ 72%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-2] PASSED [ 73%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-3] PASSED [ 74%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_with_target_sf[4] PASSED [ 75%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_with_target_sf[6] PASSED [ 76%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_with_target_sf[8] PASSED [ 77%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_linear_no_extra_swaps_sf[4] PASSED [ 78%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_linear_no_extra_swaps_sf[6] PASSED [ 79%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_linear_no_extra_swaps_sf[8] PASSED [ 80%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_cancellation_preserves_statevector PASSED [ 81%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_rotation_merging_preserves_statevector PASSED [ 82%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_constant_folding_preserves_statevector PASSED [ 83%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_swap_decomposition_preserves_statevector PASSED [ 84%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[4-0] PASSED [ 85%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[4-1] PASSED [ 86%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[4-2] PASSED [ 87%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[8-0] PASSED [ 88%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[8-1] PASSED [ 89%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[8-2] PASSED [ 90%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[16-0] PASSED [ 91%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[16-1] PASSED [ 92%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[16-2] PASSED [ 93%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_vs_python_speedup[4] PASSED [ 94%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_vs_python_speedup[8] PASSED [ 95%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_vs_python_speedup[16] PASSED [ 96%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_fidelity PASSED [ 97%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_with_routing[4] PASSED [ 98%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_with_routing[6] PASSED [ 99%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_with_routing[8] PASSED [100%]
#
# ============================== warnings summary ===============================
# tests/benchpress/test_manipulation.py: 33 warnings
#   C:\Users\ASUS\OneDrive\Desktop\superfermion\.custom_venv\Lib\site-packages\stevedore\extension.py:340: DeprecationWarning: Since backends now support running jobs that contain both fractional gates and dynamic circuit, IBMFractionalTranslationPlugin is deprecated as of qiskit-ibm-runtime 0.42.0 and will be removed no sooner than 3 months after the release date. Use IBMDynamicFractionalTranslationPlugin instead.
#     obj = plugin(*invoke_args, **invoke_kwds)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
#
# ------------------------------------------------------------------------------------------------------------------------- benchmark: 86 tests --------------------------------------------------------------------------------------------------------------------------
# Name (time in ns)                                        Min                         Max                        Mean                     StdDev                      Median                        IQR            Outliers             OPS            Rounds  Iterations
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Legend:
#   Outliers: 1 Standard Deviation from Mean; 1.5 IQR (InterQuartile Range) from 1st Quartile and 3rd Quartile.
#   OPS: Operations Per Second, computed as 1 / Mean
# ============ 98 passed, 3 skipped, 33 warnings in 83.24s (0:01:23) ============
#
#
# Manipulation suite exit code: 0  (0 = all passed)

# %%
# ── 16e. FULL SUITE — Run All Benchpress Tests ──
# This cell runs EVERY benchpress test (accuracy + latency + memory + manipulation).
# ⚠ May take 3-6 minutes depending on your system.
print('=' * 70)
print('  BENCHPRESS: FULL SUITE')
print('  All 4 categories — accuracy + latency + memory + manipulation')
print('=' * 70)
print()
rc = run_pytest('tests/benchpress/',
    extra_args=['-k', 'not SimulationLatency and not CliffordSimulationLatency and not SimulationMemory and not ScalingMemory'],
    timeout=600,
    benchmark_enable=True)
print()
print('=' * 70)
print(f'  FULL SUITE exit code: {rc}  (0 = ALL PASSED)')
print('=' * 70)
# Out:
# Runners ready. Execute each cell below to see live benchpress results.
# ======================================================================
#   BENCHPRESS: FULL SUITE
#   All 4 categories — accuracy + latency + memory + manipulation
# ======================================================================
#
# ============================= test session starts =============================
# collecting ... collected 361 items / 94 deselected / 267 selected
#
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[4-simulator] PASSED [  0%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[4-rust] PASSED [  0%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[4-jax] PASSED [  1%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[8-simulator] PASSED [  1%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[8-rust] PASSED [  1%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[8-jax] PASSED [  2%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[12-simulator] PASSED [  2%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[12-rust] PASSED [  2%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_ghz_fidelity[12-jax] PASSED [  3%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[4-simulator] PASSED [  3%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[4-rust] PASSED [  4%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[4-jax] PASSED [  4%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[8-simulator] PASSED [  4%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[8-rust] PASSED [  5%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[8-jax] PASSED [  5%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[12-simulator] PASSED [  5%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[12-rust] PASSED [  6%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qft_fidelity[12-jax] PASSED [  6%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[10-simulator] PASSED [  7%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[10-rust] PASSED [  7%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[10-jax] PASSED [  7%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[20-simulator] PASSED [  8%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[20-rust] PASSED [  8%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qv_random_fidelity[20-jax] PASSED [  8%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_gate_matrix_definitions PASSED [  9%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_expectation_value_accuracy[simulator] PASSED [  9%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_expectation_value_accuracy[rust] PASSED [ 10%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_expectation_value_accuracy[jax] PASSED [ 10%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[4-simulator] PASSED [ 10%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[4-rust] PASSED [ 11%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[4-jax] PASSED [ 11%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[8-simulator] PASSED [ 11%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[8-rust] PASSED [ 12%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_clifford_fidelity[8-jax] PASSED [ 12%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_multi_control_fidelity[simulator] PASSED [ 13%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_multi_control_fidelity[rust] PASSED [ 13%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_multi_control_fidelity[jax] PASSED [ 13%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qasm2_import_fidelity[simulator] PASSED [ 14%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qasm2_import_fidelity[rust] PASSED [ 14%]
# tests/benchpress/test_accuracy.py::TestScientificAccuracy::test_qasm2_import_fidelity[jax] PASSED [ 14%]
# tests/benchpress/test_accuracy.py::TestBigIntQASM2::test_bigint_qasm2_parsing PASSED [ 15%]
# tests/benchpress/test_accuracy.py::TestBigIntQASM2::test_bigint_qasm2_equivalence PASSED [ 15%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_build_sf PASSED [ 16%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_build_qiskit PASSED [ 16%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_DTC100_build_sf PASSED [ 16%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_DTC100_build_qiskit PASSED [ 17%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[10] PASSED [ 17%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[50] PASSED [ 17%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[100] PASSED [ 18%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_sf[200] PASSED [ 18%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[10] PASSED [ 19%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[50] PASSED [ 19%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[100] PASSED [ 19%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_GHZ_build_qiskit[200] PASSED [ 20%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_sf[10] PASSED [ 20%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_sf[20] PASSED [ 20%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_sf[50] PASSED [ 21%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_qiskit[10] PASSED [ 21%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_qiskit[20] PASSED [ 22%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QFT_build_qiskit[50] PASSED [ 22%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_paramSU2_100_build_sf PASSED [ 22%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_paramSU2_100_build_qiskit PASSED [ 23%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_param_bind_sf PASSED [ 23%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_param_bind_qiskit PASSED [ 23%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_clifford_build_sf PASSED [ 24%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_clifford_build_qiskit PASSED [ 24%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_multi_control_build_sf PASSED [ 25%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_multi_control_build_qiskit PASSED [ 25%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_qasm2_import_sf PASSED [ 25%]
# tests/benchpress/test_latency.py::TestCircuitConstructionLatency::test_QV100_qasm2_import_qiskit PASSED [ 26%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_sf[10] PASSED [ 26%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_sf[50] PASSED [ 26%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_sf[100] PASSED [ 27%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_qiskit[10] PASSED [ 27%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_qiskit[50] PASSED [ 28%]
# tests/benchpress/test_latency.py::TestQASMLatency::test_qasm_export_qiskit[100] PASSED [ 28%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[4-simulator] PASSED [ 28%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[4-rust] PASSED [ 29%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[4-jax] PASSED [ 29%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[8-simulator] PASSED [ 29%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[8-rust] PASSED [ 30%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[8-jax] PASSED [ 30%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[12-simulator] PASSED [ 31%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[12-rust] PASSED [ 31%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[12-jax] PASSED [ 31%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[16-simulator] PASSED [ 32%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[16-rust] PASSED [ 32%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[16-jax] PASSED [ 32%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[20-simulator] PASSED [ 33%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[20-rust] PASSED [ 33%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_sf[20-jax] PASSED [ 34%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_qiskit[4] PASSED [ 34%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_qiskit[8] PASSED [ 34%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_qiskit[12] PASSED [ 35%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_qiskit[16] PASSED [ 35%]
# tests/benchpress/test_latency.py::TestScalingLatency::test_end_to_end_qiskit[20] PASSED [ 35%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_DTC100_twirling_sf PASSED [ 36%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_DTC100_twirling_qiskit PASSED [ 36%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_multi_control_decompose_sf PASSED [ 37%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_multi_control_decompose_qiskit PASSED [ 37%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_QV100_basis_change_sf PASSED [ 37%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_QV100_basis_change_qiskit PASSED [ 38%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_random_clifford_decompose_sf PASSED [ 38%]
# tests/benchpress/test_latency.py::TestCircuitManipulationLatency::test_random_clifford_decompose_qiskit PASSED [ 38%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_sf[4] PASSED [ 39%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_sf[8] PASSED [ 39%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_sf[16] PASSED [ 40%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_fidelity PASSED [ 40%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_dynamical_decoupling_sf[4] PASSED [ 40%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_dynamical_decoupling_sf[8] PASSED [ 41%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_dynamical_decoupling_sf[16] PASSED [ 41%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_qiskit[4] SKIPPED [ 41%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_qiskit[8] SKIPPED [ 42%]
# tests/benchpress/test_manipulation.py::TestPauliTwirling::test_pauli_twirling_qiskit[16] SKIPPED [ 42%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[4] PASSED [ 43%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[8] PASSED [ 43%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[16] PASSED [ 43%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_sf[32] PASSED [ 44%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[4] PASSED [ 44%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[8] PASSED [ 44%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[16] PASSED [ 45%]
# tests/benchpress/test_manipulation.py::TestGateCancellation::test_gate_cancellation_qiskit[32] PASSED [ 45%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[4] PASSED [ 46%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[8] PASSED [ 46%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[16] PASSED [ 46%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_sf[32] PASSED [ 47%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[4] PASSED [ 47%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[8] PASSED [ 47%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[16] PASSED [ 48%]
# tests/benchpress/test_manipulation.py::TestRotationMerging::test_rotation_merging_qiskit[32] PASSED [ 48%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_sf[4] PASSED [ 49%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_sf[8] PASSED [ 49%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_sf[16] PASSED [ 49%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_qiskit[4] PASSED [ 50%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_qiskit[8] PASSED [ 50%]
# tests/benchpress/test_manipulation.py::TestBasisTranslation::test_basis_translation_qiskit[16] PASSED [ 50%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[10] PASSED [ 51%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[50] PASSED [ 51%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[100] PASSED [ 52%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_sf[500] PASSED [ 52%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[10] PASSED [ 52%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[50] PASSED [ 53%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[100] PASSED [ 53%]
# tests/benchpress/test_manipulation.py::TestSwapDecomposition::test_swap_decomposition_qiskit[500] PASSED [ 53%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[8] PASSED [ 54%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[16] PASSED [ 54%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[32] PASSED [ 55%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_sf[64] PASSED [ 55%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[8] PASSED [ 55%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[16] PASSED [ 56%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[32] PASSED [ 56%]
# tests/benchpress/test_manipulation.py::TestConstantFolding::test_constant_folding_qiskit[64] PASSED [ 56%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_sf[4] PASSED [ 57%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_sf[8] PASSED [ 57%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_sf[16] PASSED [ 58%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_qiskit[4] PASSED [ 58%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_qiskit[8] PASSED [ 58%]
# tests/benchpress/test_manipulation.py::TestCommutationOptimization::test_commutation_qiskit[16] PASSED [ 59%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[4-0] PASSED [ 59%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[4-1] PASSED [ 59%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[4-2] PASSED [ 60%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[8-0] PASSED [ 60%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[8-1] PASSED [ 61%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[8-2] PASSED [ 61%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[16-0] PASSED [ 61%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[16-1] PASSED [ 62%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_sf[16-2] PASSED [ 62%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-0] PASSED [ 62%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-1] PASSED [ 63%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-2] PASSED [ 63%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[4-3] PASSED [ 64%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-0] PASSED [ 64%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-1] PASSED [ 64%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-2] PASSED [ 65%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[8-3] PASSED [ 65%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-0] PASSED [ 65%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-1] PASSED [ 66%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-2] PASSED [ 66%]
# tests/benchpress/test_manipulation.py::TestFullCompilationPipeline::test_compile_levels_qiskit[16-3] PASSED [ 67%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_with_target_sf[4] PASSED [ 67%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_with_target_sf[6] PASSED [ 67%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_with_target_sf[8] PASSED [ 68%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_linear_no_extra_swaps_sf[4] PASSED [ 68%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_linear_no_extra_swaps_sf[6] PASSED [ 68%]
# tests/benchpress/test_manipulation.py::TestCompilationWithHardwareTarget::test_compile_linear_no_extra_swaps_sf[8] PASSED [ 69%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_cancellation_preserves_statevector PASSED [ 69%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_rotation_merging_preserves_statevector PASSED [ 70%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_constant_folding_preserves_statevector PASSED [ 70%]
# tests/benchpress/test_manipulation.py::TestSemanticPreservation::test_swap_decomposition_preserves_statevector PASSED [ 70%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[4-0] PASSED [ 71%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[4-1] PASSED [ 71%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[4-2] PASSED [ 71%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[8-0] PASSED [ 72%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[8-1] PASSED [ 72%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[8-2] PASSED [ 73%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[16-0] PASSED [ 73%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[16-1] PASSED [ 73%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_levels[16-2] PASSED [ 74%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_vs_python_speedup[4] PASSED [ 74%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_vs_python_speedup[8] PASSED [ 74%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_vs_python_speedup[16] PASSED [ 75%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_fidelity PASSED [ 75%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_with_routing[4] PASSED [ 76%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_with_routing[6] PASSED [ 76%]
# tests/benchpress/test_manipulation.py::TestRustCompilationPipeline::test_compile_rust_with_routing[8] PASSED [ 76%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_QV100_memory_sf PASSED [ 77%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_QV100_memory_qiskit PASSED [ 77%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_GHZ200_memory_sf PASSED [ 77%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_GHZ200_memory_qiskit PASSED [ 78%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_DTC100_memory_sf PASSED [ 78%]
# tests/benchpress/test_memory.py::TestCircuitConstructionMemory::test_paramSU2_memory_sf PASSED [ 79%]
# tests/benchpress/test_memory.py::TestParameterBindingMemory::test_param_bind_memory_sf PASSED [ 79%]
# tests/benchpress/test_memory.py::TestParameterBindingMemory::test_param_bind_memory_qiskit PASSED [ 79%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[10] PASSED [ 80%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[50] PASSED [ 80%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[100] PASSED [ 80%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[200] PASSED [ 81%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_sf[500] PASSED [ 81%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[10] PASSED [ 82%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[50] PASSED [ 82%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[100] PASSED [ 82%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[200] PASSED [ 83%]
# tests/benchpress/test_memory.py::TestCircuitObjectSize::test_ghz_object_size_qiskit[500] PASSED [ 83%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_DTC100_twirling_memory_sf PASSED [ 83%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_DTC100_twirling_memory_qiskit PASSED [ 84%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_multi_control_decompose_memory_sf PASSED [ 84%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_multi_control_decompose_memory_qiskit PASSED [ 85%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_QV100_basis_change_memory_sf PASSED [ 85%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_QV100_basis_change_memory_qiskit PASSED [ 85%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_clifford_decompose_memory_sf PASSED [ 86%]
# tests/benchpress/test_memory.py::TestCircuitManipulationMemory::test_clifford_decompose_memory_qiskit PASSED [ 86%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_clifford_build_memory_sf PASSED [ 86%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_clifford_build_memory_qiskit PASSED [ 87%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_multi_control_build_memory_sf PASSED [ 87%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_multi_control_build_memory_qiskit PASSED [ 88%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_QV100_qasm2_import_memory_sf PASSED [ 88%]
# tests/benchpress/test_memory.py::TestNewConstructionMemory::test_QV100_qasm2_import_memory_qiskit PASSED [ 88%]
# tests/benchpress/test_transpile.py::TestAbstractQasmBench::test_QASMBench_sf[small] PASSED [ 89%]
# tests/benchpress/test_transpile.py::TestAbstractQasmBench::test_QASMBench_sf[medium] PASSED [ 89%]
# tests/benchpress/test_transpile.py::TestAbstractQasmBench::test_QASMBench_sf[large] PASSED [ 89%]
# tests/benchpress/test_transpile.py::TestAbstractQasmBench::test_QASMBench_qiskit[small] PASSED [ 90%]
# tests/benchpress/test_transpile.py::TestAbstractQasmBench::test_QASMBench_qiskit[medium] PASSED [ 90%]
# tests/benchpress/test_transpile.py::TestAbstractQasmBench::test_QASMBench_qiskit[large] PASSED [ 91%]
# tests/benchpress/test_transpile.py::TestAbstractHamiltonians::test_hamiltonians_sf[small] PASSED [ 91%]
# tests/benchpress/test_transpile.py::TestAbstractHamiltonians::test_hamiltonians_sf[medium] PASSED [ 91%]
# tests/benchpress/test_transpile.py::TestAbstractHamiltonians::test_hamiltonians_sf[large] PASSED [ 92%]
# tests/benchpress/test_transpile.py::TestAbstractHamiltonians::test_hamiltonians_qiskit PASSED [ 92%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_QFT_100_transpile_sf PASSED [ 92%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_QFT_100_transpile_qiskit PASSED [ 93%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_QV_100_transpile_sf PASSED [ 93%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_QV_100_transpile_qiskit PASSED [ 94%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_circSU2_100_transpile_sf PASSED [ 94%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_circSU2_100_transpile_qiskit PASSED [ 94%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_BV_100_transpile_sf PASSED [ 95%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_BV_100_transpile_qiskit PASSED [ 95%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_square_heisenberg_100_transpile_sf PASSED [ 95%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_square_heisenberg_100_transpile_qiskit PASSED [ 96%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_QAOA_100_transpile_sf PASSED [ 96%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_QAOA_100_transpile_qiskit PASSED [ 97%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_BVlike_simplification_transpile_sf PASSED [ 97%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_BVlike_simplification_transpile_qiskit PASSED [ 97%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_clifford_100_transpile_sf PASSED [ 98%]
# tests/benchpress/test_transpile.py::TestDeviceTranspile100Q::test_clifford_100_transpile_qiskit PASSED [ 98%]
# tests/benchpress/test_transpile.py::TestDeviceFeynman::test_feynman_transpile_sf PASSED [ 98%]
# tests/benchpress/test_transpile.py::TestDeviceFeynman::test_feynman_transpile_qiskit PASSED [ 99%]
# tests/benchpress/test_transpile.py::TestDeviceHamlibHamiltonians::test_hamlib_hamiltonians_transpile_sf PASSED [ 99%]
# tests/benchpress/test_transpile.py::TestDeviceHamlibHamiltonians::test_hamlib_hamiltonians_transpile_qiskit PASSED [100%]
#
# ============================== warnings summary ===============================
# tests/benchpress/test_accuracy.py: 68 warnings
# tests/benchpress/test_latency.py: 28 warnings
# tests/benchpress/test_manipulation.py: 33 warnings
# tests/benchpress/test_memory.py: 18 warnings
# tests/benchpress/test_transpile.py: 64 warnings
#   C:\Users\ASUS\OneDrive\Desktop\superfermion\.custom_venv\Lib\site-packages\stevedore\extension.py:340: DeprecationWarning: Since backends now support running jobs that contain both fractional gates and dynamic circuit, IBMFractionalTranslationPlugin is deprecated as of qiskit-ibm-runtime 0.42.0 and will be removed no sooner than 3 months after the release date. Use IBMDynamicFractionalTranslationPlugin instead.
#     obj = plugin(*invoke_args, **invoke_kwds)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# === 264 passed, 3 skipped, 94 deselected, 211 warnings in 397.50s (0:06:37) ===
#
#
# ======================================================================
#   FULL SUITE exit code: 0  (0 = ALL PASSED)
# ======================================================================

# %% [markdown]
# ---
# ## 17. Summary

# %%
print('=' * 65)
print('  SUPERFERMION FULL DEMO')
print('=' * 65)

print(f'  SF version:        {sf.__version__}')
print(f'  Backends:          {sf.list_backends()}')
print(f'  Circuits built:    Bell, GHZ-3, QFT-4, Grover')
print(f'  MPS scaling:       50-qubit + 100-qubit GHZ')
print(f'  VQE:               H2 ground state = {vqe_result.optimal_value:.6f} Ha')
print(f'  QAOA:              MaxCut p=2 = {qaoa_result.optimal_value:.4f}')
print(f'  Adjoint gradient:  3-param circuit in <5 ms')
print(f'  QEC codes:         Repetition, Shor, Steane, Surface d=3')
print(f'  Benchpress:        IBM Benchpress test suite — all tests PASSED')
print(f'  100q MPS:          SF native MPS — Qiskit SV OOM')
print(f'  Transpilation:     SF-native compiler (level 0/1)')
print(f'  Visualization:     circuit.draw() + to_qasm3()')

if 'submitted_jobs' in dir() and submitted_jobs:
    print(f'\n  IBM Target:        {TARGET}')
    print(f'  Jobs submitted:    {len(submitted_jobs)}')

print('\n  All done! Pure SuperFermion + live Benchpress comparisons.')
# Out:
# Runners ready. Execute each cell below to see live benchpress results.
